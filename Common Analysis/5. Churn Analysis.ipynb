# %%
from IPython.display import display, HTML

# Convert Periods to string for safety
cohort_churn['cohort_month'] = cohort_churn['cohort_month'].astype(str)

# Line chart of churn rate by cohort
fig = px.line(
    cohort_churn,
    x='cohort_month',
    y='churn_rate_pct',
    title='Churn Rate by Customer Cohort',
    labels={'cohort_month':'Cohort Month','churn_rate_pct':'Churn Rate (%)'},
    markers=True
)

fig.update_layout(xaxis_tickangle=-45, height=500, template="plotly_white")

# --- Proper inline display ---
display(HTML(fig.to_html(include_plotlyjs='cdn')))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
